# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE,ADASYN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data files/Bank_Imbalance.csv")
data.head()
# Out:
#    age  duration  emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 0   44       210           1.4          93.444          -36.1      4.963
# 1   53       138          -0.1          93.200          -42.0      4.021
# 2   28       339          -1.7          94.055          -39.8      0.729
# 3   39       185          -1.8          93.075          -47.1      1.405
# 4   55       137          -2.9          92.201          -31.4      0.869
#
#    nr_employed  y
# 0       5228.1  1
# 1       5195.8  1
# 2       4991.6  1
# 3       5099.1  1
# 4       5076.2  1

# %%
data["y"].value_counts()
# Out:
# 1    2396
# 0     603
# Name: y, dtype: int64

# %%
x=data.iloc[:,:7]
y=data.iloc[:,7]

# %%
smt=SMOTE()

# %%
x_sm,y_sm=smt.fit_resample(x,y)

# %%
x.shape
# Out:
# (2999, 7)

# %%
x_sm.shape
# Out:
# (4792, 7)

# %%
len(y_sm)
# Out:
# 4792

# %%
y.value_counts()
# Out:
# 1    2396
# 0     603
# Name: y, dtype: int64

# %%
y_sm.value_counts()
# Out:
# 1    2396
# 0    2396
# Name: y, dtype: int64

# %%
ada=ADASYN()
x_ad,y_ad=smt.fit_resample(x,y)

# %%
y_ad.value_counts()
# Out:
# 1    2396
# 0    2396
# Name: y, dtype: int64
